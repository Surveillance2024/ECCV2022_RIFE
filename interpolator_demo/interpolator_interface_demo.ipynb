# %%
from eccv2022_rife.InterpolatorInterface import InterpolatorInterface

# %%
interpolator = InterpolatorInterface()
# Out:
# model_ver: 2
# Loaded v3.x HD model.

# %%
interpolator.generate(
    imgs=('img0.png', 'img1.png'),
    exp=1, outputdir="interpolator_out")
# Out:
# ['interpolator_out/img3.png',
#  'interpolator_out/img4.png',
#  'interpolator_out/img5.png']

# %%
from eccv2022_rife.model.oldmodel.RIFE_HDv2 import Model
model = Model()
model.load_model(".venv/lib/python3.13/site-packages/eccv2022_rife/train_log", -1)
print("Loaded v2.x HD model.")
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# Cell In[8], line 3
#       1 from eccv2022_rife.model.oldmodel.RIFE_HDv2 import Model
#       2 model = Model()
# ----> 3 model.load_model(".venv/lib/python3.13/site-packages/eccv2022_rife/train_log", -1)
#       4 print("Loaded v2.x HD model.")
#
# File ~/Desktop/Lessons/lyn_lab/ECCV2022_RIFE/interpolator_demo/.venv/lib/python3.13/site-packages/eccv2022_rife/model/oldmodel/RIFE_HDv2.py:163, in Model.load_model(self, path, rank)
#     161         return param
#     162 if rank <= 0:
# --> 163     self.flownet.load_state_dict(
#     164         convert(torch.load('{}/flownet.pkl'.format(path), map_location=device)))
#     165     self.contextnet.load_state_dict(
#     166         convert(torch.load('{}/contextnet.pkl'.format(path), map_location=device)))
#     167     self.fusionnet.load_state_dict(
# ...
